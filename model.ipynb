# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import RidgeCV
from sklearn.feature_selection import SelectKBest, f_regression
import warnings
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
# !pip install catboost
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.neural_network import MLPRegressor


warnings.filterwarnings("ignore")
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (8.5.0)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.6 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
# Load data
train = pd.read_csv("./dataset/train.csv")
test = pd.read_csv("./dataset/test.csv")
sample_submission = pd.read_csv("./dataset/sample_solution.csv")

print("Train shape:", train.shape)
print("Test shape:", test.shape)

# Display basic info

print("\nTrain data info:")
print(train.head())

print("\nMissing values in train:", train.isnull().sum().sum())
print("Missing values in test:", test.isnull().sum().sum())
# Out:
# Train shape: (2000, 65)
# Test shape: (500, 56)
#
# Train data info:
#    Component1_fraction  Component2_fraction  Component3_fraction  \
# 0                 0.21                 0.00                 0.42
# 1                 0.02                 0.33                 0.19
# 2                 0.08                 0.08                 0.18
# 3                 0.25                 0.42                 0.00
# 4                 0.26                 0.16                 0.08
#
#    Component4_fraction  Component5_fraction  Component1_Property1  \
# 0                 0.25                 0.12             -0.021782
# 1                 0.46                 0.00             -0.224339
# 2                 0.50                 0.16              0.457763
# 3                 0.07                 0.26             -0.577734
# 4                 0.50                 0.00              0.120415
#
#    Component2_Property1  Component3_Property1  Component4_Property1  \
# 0              1.981251              0.020036              0.140315
# 1              1.148036             -1.107840              0.149533
# 2              0.242591             -0.922492              0.908213
# 3             -0.930826              0.815284              0.447514
# 4              0.666268             -0.626934              2.725357
#
#    Component5_Property1  ...  BlendProperty1  BlendProperty2  BlendProperty3  \
# 0              1.032029  ...        0.489143        0.607589        0.321670
# 1             -0.354000  ...       -1.257481       -1.475283       -0.437385
# 2              0.972003  ...        1.784349        0.450467        0.622687
# 3              0.455717  ...       -0.066422        0.483730       -1.865442
# 4              0.392259  ...       -0.118913       -1.172398        0.301785
#
#    BlendProperty4  BlendProperty5  BlendProperty6  BlendProperty7  \
# 0       -1.236055        1.601132        1.384662        0.305850
# 1       -1.402911        0.147941       -1.143244       -0.439171
# 2        1.375614       -0.428790        1.161616        0.601289
# 3       -0.046295       -0.163820       -0.209693       -1.840566
# 4       -1.787407       -0.493361       -0.528049        0.286344
#
#    BlendProperty8  BlendProperty9  BlendProperty10
# 0        0.193460        0.580374        -0.762738
# 1       -1.379041       -1.280989        -0.503625
# 2        0.872950        0.660000         2.024576
# 3        0.300293       -0.351336        -1.551914
# 4       -0.265192        0.430513         0.735073
#
# [5 rows x 65 columns]
#
# Missing values in train: 0
# Missing values in test: 0

# %%
# Identify property columns
property_cols = [col for col in train.columns if "_Property" in col]

def add_aggregate_features(df):
    df["prop_mean"] = df[property_cols].mean(axis=1)
    df["prop_std"] = df[property_cols].std(axis=1)
    df["prop_min"] = df[property_cols].min(axis=1)
    df["prop_max"] = df[property_cols].max(axis=1)
    df["prop_range"] = df["prop_max"] - df["prop_min"]
    df["prop_median"] = df[property_cols].median(axis=1)
    return df

train = add_aggregate_features(train)
test = add_aggregate_features(test)

# %%
def add_cross_component_stats(df):
    for prop_idx in range(1, 11):
        cols = [f"Component{i}_Property{prop_idx}" for i in range(1, 6)]
        df[f"Property{prop_idx}_mean"] = df[cols].mean(axis=1)
        df[f"Property{prop_idx}_std"] = df[cols].std(axis=1)
        df[f"Property{prop_idx}_min"] = df[cols].min(axis=1)
        df[f"Property{prop_idx}_max"] = df[cols].max(axis=1)
        df[f"Property{prop_idx}_range"] = df[f"Property{prop_idx}_max"] - df[f"Property{prop_idx}_min"]
    return df

train = add_cross_component_stats(train)
test = add_cross_component_stats(test)

# %%
train = train.loc[:, ~train.columns.str.contains("^Weighted_Property")]
test = test.loc[:, ~test.columns.str.contains("^Weighted_Property")]
train = train.loc[:, ~train.columns.str.contains("^C[1-5]_P[1-9]_weighted|^C[1-5]_P10_weighted")]
test = test.loc[:, ~test.columns.str.contains("^C[1-5]_P[1-9]_weighted|^C[1-5]_P10_weighted")]

# Generate weighted interaction features
for i in range(1, 6):
    for j in range(1, 11):
        train[f"C{i}_P{j}_weighted"] = train[f"Component{i}_fraction"] * train[f"Component{i}_Property{j}"]
        test[f"C{i}_P{j}_weighted"] = test[f"Component{i}_fraction"] * test[f"Component{i}_Property{j}"]

# Aggregate weighted properties
weighted_train_props = {}
weighted_test_props = {}

for j in range(1, 11):
    cols = [f"C{i}_P{j}_weighted" for i in range(1, 6)]
    weighted_train_props[f"Weighted_Property{j}"] = train[cols].sum(axis=1)
    weighted_test_props[f"Weighted_Property{j}"] = test[cols].sum(axis=1)

train = pd.concat([train, pd.DataFrame(weighted_train_props)], axis=1)
test = pd.concat([test, pd.DataFrame(weighted_test_props)], axis=1)

# %%
for j in range(1, 11):
    cols = [f"Component{i}_Property{j}" for i in range(1, 6)]
    train[f"Property{j}_diversity"] = train[cols].max(axis=1) - train[cols].min(axis=1)
    test[f"Property{j}_diversity"] = test[cols].max(axis=1) - test[cols].min(axis=1)

# %%
# Rank features
def add_rank_features(df):
    for j in range(1, 11):
        cols = [f"Component{i}_Property{j}" for i in range(1, 6)]
        df[[f"{col}_rank" for col in cols]] = df[cols].rank(axis=1, method='min')
    return df

train = add_rank_features(train)
test = add_rank_features(test)

# Entropy features
from scipy.stats import entropy

def add_entropy_features(df):
    for j in range(1, 11):
        cols = [f"Component{i}_Property{j}" for i in range(1, 6)]
        df[f"Property{j}_entropy"] = df[cols].apply(
            lambda row: entropy(np.abs(row) / np.sum(np.abs(row))), axis=1
        )
    return df

train = add_entropy_features(train)
test = add_entropy_features(test)

# %%
def add_spread_features(df):
    for j in range(1, 11):
        cols = [f"Component{i}_Property{j}" for i in range(1, 6)]
        df[f"Property{j}_range"] = df[cols].max(axis=1) - df[cols].min(axis=1)
        df[f"Property{j}_std"] = df[cols].std(axis=1)
        df[f"Property{j}_cv"] = df[cols].std(axis=1) / (df[cols].mean(axis=1) + 1e-6)
    return df
train = add_spread_features(train)
test = add_spread_features(test)

# %%
def add_zscore_features(df):
    for j in range(1, 11):
        cols = [f"Component{i}_Property{j}" for i in range(1, 6)]
        row_mean = df[cols].mean(axis=1)
        row_std = df[cols].std(axis=1) + 1e-6
        for col in cols:
            df[f"{col}_zscore"] = (df[col] - row_mean) / row_std
    return df
train = add_zscore_features(train)
test = add_zscore_features(test)

# %%
def add_linear_features(df):
    for j in range(1, 11):
        cols = [f"Component{i}_Property{j}" for i in range(1, 6)]

        row_mean = df[cols].mean(axis=1)
        row_std = df[cols].std(axis=1) + 1e-6
        row_min = df[cols].min(axis=1)
        row_max = df[cols].max(axis=1)
        row_range = row_max - row_min
        row_sum = df[cols].sum(axis=1)

        # Z-scores and other statistical features
        for col in cols:
            df[f"{col}_zscore"] = (df[col] - row_mean) / row_std
            df[f"{col}_diff_mean"] = df[col] - row_mean
            df[f"{col}_diff_min"] = df[col] - row_min
            df[f"{col}_diff_max"] = df[col] - row_max

        # Add overall statistical features for this group
        df[f"Property{j}_mean"] = row_mean
        df[f"Property{j}_std"] = row_std
        df[f"Property{j}_min"] = row_min
        df[f"Property{j}_max"] = row_max
        df[f"Property{j}_range"] = row_range
        df[f"Property{j}_sum"] = row_sum

    return df

train = add_linear_features(train)
test = add_linear_features(test)

# %%
target_cols = [f"BlendProperty{i}" for i in range(1, 11)]

X = train.drop(columns=target_cols)
y = train[target_cols]
X_test = test[X.columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
transformers=ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), X.columns)
    ],
    remainder='passthrough'
)
X = transformers.fit_transform(X)
X_test = transformers.transform(X_test)

# %%
# !pip install catboost --quiet
from catboost import CatBoostRegressor
from sklearn.multioutput import MultiOutputRegressor

cat_model = MultiOutputRegressor(CatBoostRegressor(
    iterations=2000,
    learning_rate=0.03,
    depth=6,
    random_seed=42,
    verbose=100,
    l2_leaf_reg=3,
    task_type='CPU',
))
cat_model.fit(X, y)
cat_preds = cat_model.predict(X_test)
# Out:
# 0:	learn: 0.9756385	total: 197ms	remaining: 6m 34s
# 100:	learn: 0.2704710	total: 11.9s	remaining: 3m 44s
# 200:	learn: 0.1359504	total: 23.5s	remaining: 3m 30s
# 300:	learn: 0.0844065	total: 34.9s	remaining: 3m 17s
# 400:	learn: 0.0606714	total: 46.4s	remaining: 3m 5s
# 500:	learn: 0.0490316	total: 58s	remaining: 2m 53s
# 600:	learn: 0.0416095	total: 1m 9s	remaining: 2m 40s
# 700:	learn: 0.0358545	total: 1m 22s	remaining: 2m 32s
# 800:	learn: 0.0313410	total: 1m 32s	remaining: 2m 18s
# 900:	learn: 0.0275133	total: 1m 44s	remaining: 2m 7s
# 1000:	learn: 0.0243619	total: 1m 55s	remaining: 1m 55s
# 1100:	learn: 0.0213523	total: 2m 7s	remaining: 1m 44s
# 1200:	learn: 0.0189954	total: 2m 18s	remaining: 1m 32s
# 1300:	learn: 0.0166999	total: 2m 30s	remaining: 1m 20s
# 1400:	learn: 0.0147914	total: 2m 42s	remaining: 1m 9s
# 1500:	learn: 0.0130562	total: 2m 53s	remaining: 57.6s
# 1600:	learn: 0.0115649	total: 3m 3s	remaining: 45.8s
# 1700:	learn: 0.0102636	total: 3m 19s	remaining: 35.1s
# 1800:	learn: 0.0090736	total: 3m 33s	remaining: 23.6s
# 1900:	learn: 0.0080260	total: 3m 44s	remaining: 11.7s
# 1999:	learn: 0.0071281	total: 3m 55s	remaining: 0us
# 0:	learn: 0.9876306	total: 104ms	remaining: 3m 27s
# 100:	learn: 0.2876019	total: 11.7s	remaining: 3m 39s
# 200:	learn: 0.1378019	total: 23.2s	remaining: 3m 27s
# 300:	learn: 0.0835254	total: 35.2s	remaining: 3m 18s
# 400:	learn: 0.0597540	total: 46.7s	remaining: 3m 6s
# 500:	learn: 0.0472934	total: 58.3s	remaining: 2m 54s
# 600:	learn: 0.0399424	total: 1m 9s	remaining: 2m 42s
# 700:	learn: 0.0345224	total: 1m 21s	remaining: 2m 30s
# 800:	learn: 0.0300214	total: 1m 31s	remaining: 2m 17s
# 900:	learn: 0.0263194	total: 1m 43s	remaining: 2m 5s
# 1000:	learn: 0.0233069	total: 1m 54s	remaining: 1m 54s
# 1100:	learn: 0.0205492	total: 2m 6s	remaining: 1m 43s
# 1200:	learn: 0.0181481	total: 2m 18s	remaining: 1m 31s
# 1300:	learn: 0.0160412	total: 2m 29s	remaining: 1m 20s
# 1400:	learn: 0.0142019	total: 2m 40s	remaining: 1m 8s
# 1500:	learn: 0.0125001	total: 2m 52s	remaining: 57.3s
# 1600:	learn: 0.0110490	total: 3m 3s	remaining: 45.7s
# 1700:	learn: 0.0098574	total: 3m 15s	remaining: 34.3s
# 1800:	learn: 0.0087375	total: 3m 26s	remaining: 22.8s
# 1900:	learn: 0.0077857	total: 3m 38s	remaining: 11.4s
# 1999:	learn: 0.0069200	total: 3m 49s	remaining: 0us
# 0:	learn: 0.9826438	total: 127ms	remaining: 4m 13s
# 100:	learn: 0.3061286	total: 11.8s	remaining: 3m 42s
# 200:	learn: 0.1993710	total: 23.4s	remaining: 3m 29s
# 300:	learn: 0.1509348	total: 34.9s	remaining: 3m 17s
# 400:	learn: 0.1223434	total: 46.3s	remaining: 3m 4s
# 500:	learn: 0.1028155	total: 56.9s	remaining: 2m 50s
# 600:	learn: 0.0877039	total: 1m 8s	remaining: 2m 39s
# 700:	learn: 0.0758817	total: 1m 20s	remaining: 2m 28s
# 800:	learn: 0.0663031	total: 1m 31s	remaining: 2m 17s
# 900:	learn: 0.0584079	total: 1m 43s	remaining: 2m 5s
# 1000:	learn: 0.0515344	total: 1m 55s	remaining: 1m 54s
# 1100:	learn: 0.0453722	total: 2m 6s	remaining: 1m 43s
# 1200:	learn: 0.0402139	total: 2m 18s	remaining: 1m 32s
# 1300:	learn: 0.0355477	total: 2m 29s	remaining: 1m 20s
# 1400:	learn: 0.0312746	total: 2m 40s	remaining: 1m 8s
# 1500:	learn: 0.0277408	total: 2m 51s	remaining: 57.2s
# 1600:	learn: 0.0247750	total: 3m 3s	remaining: 45.8s
# 1700:	learn: 0.0221793	total: 3m 15s	remaining: 34.3s
# 1800:	learn: 0.0198252	total: 3m 26s	remaining: 22.9s
# 1900:	learn: 0.0176928	total: 3m 38s	remaining: 11.4s
# 1999:	learn: 0.0158834	total: 3m 49s	remaining: 0us
# 0:	learn: 0.9927438	total: 104ms	remaining: 3m 27s
# 100:	learn: 0.2738582	total: 12s	remaining: 3m 44s
# 200:	learn: 0.1312437	total: 22.7s	remaining: 3m 23s
# 300:	learn: 0.0819240	total: 33.7s	remaining: 3m 10s
# 400:	learn: 0.0587988	total: 45.3s	remaining: 3m
# 500:	learn: 0.0471422	total: 56.8s	remaining: 2m 50s
# 600:	learn: 0.0395783	total: 1m 8s	remaining: 2m 39s
# 700:	learn: 0.0339288	total: 1m 20s	remaining: 2m 28s
# 800:	learn: 0.0295562	total: 1m 31s	remaining: 2m 17s
# 900:	learn: 0.0256710	total: 1m 43s	remaining: 2m 6s
# 1000:	learn: 0.0225771	total: 1m 54s	remaining: 1m 53s
# 1100:	learn: 0.0199396	total: 2m 5s	remaining: 1m 42s
# 1200:	learn: 0.0176705	total: 2m 16s	remaining: 1m 31s
# 1300:	learn: 0.0156085	total: 2m 28s	remaining: 1m 19s
# 1400:	learn: 0.0137506	total: 2m 40s	remaining: 1m 8s
# 1500:	learn: 0.0121505	total: 2m 51s	remaining: 57.1s
# 1600:	learn: 0.0108146	total: 3m 3s	remaining: 45.7s
# 1700:	learn: 0.0096065	total: 3m 14s	remaining: 34.3s
# 1800:	learn: 0.0084751	total: 3m 26s	remaining: 22.8s
# 1900:	learn: 0.0075021	total: 3m 36s	remaining: 11.3s
# 1999:	learn: 0.0067056	total: 3m 48s	remaining: 0us
# 0:	learn: 0.9644807	total: 155ms	remaining: 5m 9s
# 100:	learn: 0.1888280	total: 11.9s	remaining: 3m 43s
# 200:	learn: 0.1048340	total: 23.5s	remaining: 3m 30s
# 300:	learn: 0.0758578	total: 35.2s	remaining: 3m 18s
# 400:	learn: 0.0588158	total: 46.7s	remaining: 3m 6s
# 500:	learn: 0.0478969	total: 58.4s	remaining: 2m 54s
# 600:	learn: 0.0394010	total: 1m 10s	remaining: 2m 42s
# 700:	learn: 0.0336855	total: 1m 21s	remaining: 2m 31s
# 800:	learn: 0.0287810	total: 1m 32s	remaining: 2m 18s
# 900:	learn: 0.0248051	total: 1m 43s	remaining: 2m 6s
# 1000:	learn: 0.0211700	total: 1m 55s	remaining: 1m 55s
# 1100:	learn: 0.0185357	total: 2m 6s	remaining: 1m 43s
# 1200:	learn: 0.0163074	total: 2m 18s	remaining: 1m 32s
# 1300:	learn: 0.0143645	total: 2m 30s	remaining: 1m 20s
# 1400:	learn: 0.0127129	total: 2m 41s	remaining: 1m 9s
# 1500:	learn: 0.0113522	total: 2m 53s	remaining: 57.6s
# 1600:	learn: 0.0101079	total: 3m 4s	remaining: 46s
# 1700:	learn: 0.0089716	total: 3m 15s	remaining: 34.3s
# 1800:	learn: 0.0079733	total: 3m 26s	remaining: 22.8s
# 1900:	learn: 0.0070679	total: 3m 38s	remaining: 11.4s
# 1999:	learn: 0.0062903	total: 3m 49s	remaining: 0us
# 0:	learn: 0.9885813	total: 129ms	remaining: 4m 17s
# 100:	learn: 0.2513865	total: 11.8s	remaining: 3m 41s
# 200:	learn: 0.1178775	total: 23.4s	remaining: 3m 29s
# 300:	learn: 0.0694097	total: 35s	remaining: 3m 17s
# 400:	learn: 0.0505914	total: 46.7s	remaining: 3m 6s
# 500:	learn: 0.0410430	total: 57.7s	remaining: 2m 52s
# 600:	learn: 0.0347316	total: 1m 8s	remaining: 2m 39s
# 700:	learn: 0.0298943	total: 1m 20s	remaining: 2m 28s
# 800:	learn: 0.0260558	total: 1m 31s	remaining: 2m 17s
# 900:	learn: 0.0227909	total: 1m 43s	remaining: 2m 6s
# 1000:	learn: 0.0200436	total: 1m 55s	remaining: 1m 54s
# 1100:	learn: 0.0178813	total: 2m 6s	remaining: 1m 43s
# 1200:	learn: 0.0157761	total: 2m 18s	remaining: 1m 32s
# 1300:	learn: 0.0140327	total: 2m 30s	remaining: 1m 20s
# 1400:	learn: 0.0124763	total: 2m 40s	remaining: 1m 8s
# 1500:	learn: 0.0111688	total: 2m 52s	remaining: 57.2s
# 1600:	learn: 0.0098925	total: 3m 3s	remaining: 45.8s
# 1700:	learn: 0.0088141	total: 3m 15s	remaining: 34.3s
# 1800:	learn: 0.0078944	total: 3m 26s	remaining: 22.9s
# 1900:	learn: 0.0070231	total: 3m 38s	remaining: 11.4s
# 1999:	learn: 0.0062813	total: 3m 50s	remaining: 0us
# 0:	learn: 0.9841062	total: 104ms	remaining: 3m 28s
# 100:	learn: 0.3105003	total: 11.8s	remaining: 3m 42s
# 200:	learn: 0.2017357	total: 23.4s	remaining: 3m 29s
# 300:	learn: 0.1525258	total: 33.9s	remaining: 3m 11s
# 400:	learn: 0.1219624	total: 45.4s	remaining: 3m
# 500:	learn: 0.1027882	total: 57s	remaining: 2m 50s
# 600:	learn: 0.0884186	total: 1m 8s	remaining: 2m 39s
# 700:	learn: 0.0768264	total: 1m 20s	remaining: 2m 28s
# 800:	learn: 0.0673481	total: 1m 31s	remaining: 2m 17s
# 900:	learn: 0.0589221	total: 1m 43s	remaining: 2m 6s
# 1000:	learn: 0.0520125	total: 1m 55s	remaining: 1m 55s
# 1100:	learn: 0.0461360	total: 2m 6s	remaining: 1m 43s
# 1200:	learn: 0.0406244	total: 2m 17s	remaining: 1m 31s
# 1300:	learn: 0.0360183	total: 2m 29s	remaining: 1m 20s
# 1400:	learn: 0.0319883	total: 2m 40s	remaining: 1m 8s
# 1500:	learn: 0.0282112	total: 2m 52s	remaining: 57.4s
# 1600:	learn: 0.0249451	total: 3m 4s	remaining: 46s
# 1700:	learn: 0.0221302	total: 3m 16s	remaining: 34.5s
# 1800:	learn: 0.0196221	total: 3m 28s	remaining: 23s
# 1900:	learn: 0.0173636	total: 3m 40s	remaining: 11.5s
# 1999:	learn: 0.0154503	total: 3m 51s	remaining: 0us
# 0:	learn: 0.9816988	total: 178ms	remaining: 5m 55s
# 100:	learn: 0.3385285	total: 12.6s	remaining: 3m 57s
# 200:	learn: 0.1996556	total: 23.7s	remaining: 3m 32s
# 300:	learn: 0.1358564	total: 34.9s	remaining: 3m 17s
# 400:	learn: 0.1021641	total: 46.6s	remaining: 3m 5s
# 500:	learn: 0.0834021	total: 58.3s	remaining: 2m 54s
# 600:	learn: 0.0710403	total: 1m 9s	remaining: 2m 42s
# 700:	learn: 0.0615599	total: 1m 21s	remaining: 2m 31s
# 800:	learn: 0.0536558	total: 1m 33s	remaining: 2m 19s
# 900:	learn: 0.0474295	total: 1m 44s	remaining: 2m 8s
# 1000:	learn: 0.0416639	total: 1m 56s	remaining: 1m 56s
# 1100:	learn: 0.0368944	total: 2m 7s	remaining: 1m 43s
# 1200:	learn: 0.0325715	total: 2m 18s	remaining: 1m 32s
# 1300:	learn: 0.0289751	total: 2m 30s	remaining: 1m 20s
# 1400:	learn: 0.0258703	total: 2m 41s	remaining: 1m 9s
# 1500:	learn: 0.0228053	total: 2m 53s	remaining: 57.7s
# 1600:	learn: 0.0201827	total: 3m 5s	remaining: 46.1s
# 1700:	learn: 0.0180688	total: 3m 16s	remaining: 34.6s
# 1800:	learn: 0.0160673	total: 3m 28s	remaining: 23s
# 1900:	learn: 0.0143666	total: 3m 39s	remaining: 11.4s
# 1999:	learn: 0.0128071	total: 3m 49s	remaining: 0us
# 0:	learn: 0.9834254	total: 162ms	remaining: 5m 24s
# 100:	learn: 0.3764580	total: 11.9s	remaining: 3m 43s
# 200:	learn: 0.2534822	total: 23.6s	remaining: 3m 31s
# 300:	learn: 0.1962224	total: 35.2s	remaining: 3m 18s
# 400:	learn: 0.1613746	total: 46.9s	remaining: 3m 7s
# 500:	learn: 0.1371086	total: 58.7s	remaining: 2m 55s
# 600:	learn: 0.1192157	total: 1m 10s	remaining: 2m 43s
# 700:	learn: 0.1042869	total: 1m 22s	remaining: 2m 32s
# 800:	learn: 0.0910480	total: 1m 33s	remaining: 2m 20s
# 900:	learn: 0.0804189	total: 1m 44s	remaining: 2m 7s
# 1000:	learn: 0.0704642	total: 1m 55s	remaining: 1m 55s
# 1100:	learn: 0.0622507	total: 2m 7s	remaining: 1m 43s
# 1200:	learn: 0.0550574	total: 2m 19s	remaining: 1m 32s
# 1300:	learn: 0.0488194	total: 2m 30s	remaining: 1m 20s
# 1400:	learn: 0.0430160	total: 2m 42s	remaining: 1m 9s
# 1500:	learn: 0.0381797	total: 2m 53s	remaining: 57.8s
# 1600:	learn: 0.0340474	total: 3m 5s	remaining: 46.2s
# 1700:	learn: 0.0302197	total: 3m 16s	remaining: 34.6s
# 1800:	learn: 0.0269048	total: 3m 27s	remaining: 22.9s
# 1900:	learn: 0.0240815	total: 3m 38s	remaining: 11.4s
# 1999:	learn: 0.0215155	total: 3m 50s	remaining: 0us
# 0:	learn: 0.9726190	total: 141ms	remaining: 4m 41s
# 100:	learn: 0.2732671	total: 11.8s	remaining: 3m 41s
# 200:	learn: 0.1389701	total: 23.3s	remaining: 3m 28s
# 300:	learn: 0.0863449	total: 34.9s	remaining: 3m 17s
# 400:	learn: 0.0641844	total: 46.3s	remaining: 3m 4s
# 500:	learn: 0.0518877	total: 57.9s	remaining: 2m 53s
# 600:	learn: 0.0441445	total: 1m 9s	remaining: 2m 41s
# 700:	learn: 0.0379348	total: 1m 19s	remaining: 2m 27s
# 800:	learn: 0.0329496	total: 1m 31s	remaining: 2m 16s
# 900:	learn: 0.0288642	total: 1m 42s	remaining: 2m 5s
# 1000:	learn: 0.0252655	total: 1m 54s	remaining: 1m 54s
# 1100:	learn: 0.0221933	total: 2m 5s	remaining: 1m 42s
# 1200:	learn: 0.0193187	total: 2m 17s	remaining: 1m 31s
# 1300:	learn: 0.0170112	total: 2m 29s	remaining: 1m 20s
# 1400:	learn: 0.0149996	total: 2m 40s	remaining: 1m 8s
# 1500:	learn: 0.0132677	total: 2m 51s	remaining: 57s
# 1600:	learn: 0.0117172	total: 3m 2s	remaining: 45.5s
# 1700:	learn: 0.0103221	total: 3m 14s	remaining: 34.2s
# 1800:	learn: 0.0090916	total: 3m 26s	remaining: 22.8s
# 1900:	learn: 0.0080578	total: 3m 37s	remaining: 11.3s
# 1999:	learn: 0.0071783	total: 3m 49s	remaining: 0us

# %%
final_preds = 1.0*cat_preds
submission = pd.DataFrame(final_preds, columns=target_cols)
submission.insert(0, "ID", test["ID"].values)
submission.to_csv("submission.csv", index=False)
from google.colab import files
files.download("submission.csv")
