# %% [markdown]
# # Blend Property Prediction
#
# Predicting the resulting properties of a 5-component blend (e.g. a fuel or
# chemical formulation) from each component's mixing fraction and its own
# measured properties. This is the kind of problem that shows up directly in
# **formulation and quality control**: given raw ingredient specs and a
# target mix ratio, predict the blended product's properties before you
# actually blend it, so out-of-spec batches can be caught before production.
#
# Pipeline: engineered features (`src/features.py`) &rarr; train/val split
# &rarr; model comparison (CatBoost vs XGBoost vs LightGBM, `src/modeling.py`)
# &rarr; SHAP explainability on the winner &rarr; refit on full data &rarr;
# submission.
#
# See [`BENCHMARKS.md`](BENCHMARKS.md) for the full results table.

# %%
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

sys.path.append(str(Path.cwd()))
from src.features import build_features
from src.modeling import compare_models, save_model, shap_summary, train_val_split

pd.set_option("display.width", 120)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Load data

# %%
train = pd.read_csv("dataset/train.csv")
test = pd.read_csv("dataset/test.csv")
sample_submission = pd.read_csv("dataset/sample_solution.csv")

print("Train shape:", train.shape)
print("Test shape:", test.shape)
print("Missing values in train:", train.isnull().sum().sum())
print("Missing values in test:", test.isnull().sum().sum())
train.head()
# Out:
# Train shape: (2000, 65)
# Test shape: (500, 56)
# Missing values in train: 0
# Missing values in test: 0
#    Component1_fraction  Component2_fraction  Component3_fraction  Component4_fraction  Component5_fraction  \
# 0                 0.21                 0.00                 0.42                 0.25                 0.12
# 1                 0.02                 0.33                 0.19                 0.46                 0.00
# 2                 0.08                 0.08                 0.18                 0.50                 0.16
# 3                 0.25                 0.42                 0.00                 0.07                 0.26
# 4                 0.26                 0.16                 0.08                 0.50                 0.00
#
#    Component1_Property1  Component2_Property1  Component3_Property1  Component4_Property1  Component5_Property1  ...  \
# ...

# %% [markdown]
# ## Feature engineering
#
# All feature logic lives in `src/features.py` (unit tested in
# `tests/test_features.py`) so it's reusable outside this notebook and
# independently verifiable.

# %%
train_fe = build_features(train)
test_fe = build_features(test)
print("Engineered train shape:", train_fe.shape)
print("Engineered test shape:", test_fe.shape)
# Out:
# Engineered train shape: (2000, 471)
# Engineered test shape: (500, 462)

# %%
target_cols = [f"BlendProperty{i}" for i in range(1, 11)]
drop_cols = [c for c in ["ID"] if c in train_fe.columns]

X = train_fe.drop(columns=target_cols + drop_cols)
y = train_fe[target_cols]
X_test = test_fe[X.columns]

feature_names = list(X.columns)
print("Feature count:", len(feature_names))
# Out:
# Feature count: 461

# %%
scaler = ColumnTransformer([("num", StandardScaler(), X.columns)], remainder="passthrough")
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X.columns, index=X_test.index)

# %% [markdown]
# ## Baseline: train/val split + model comparison
#
# This is the part the original notebook skipped entirely — it fit CatBoost
# once and never checked it against a held-out set or against the other
# model families already imported. Here we hold out 20% of the training data
# and compare CatBoost, XGBoost, and LightGBM on it with matched
# hyperparameters (500 estimators, depth 6, lr 0.05).

# %%
X_tr, X_val, y_tr, y_val = train_val_split(X_scaled, y, test_size=0.2, random_state=42)

summary_df, per_target_df, fitted_models = compare_models(X_tr, y_tr, X_val, y_val, target_names=target_cols)
summary_df
# Out:
#       model  mean_MAPE  mean_MAE  mean_RMSE
# 0  CatBoost   0.773512  0.106343   0.147654
# 1  LightGBM   2.293328  0.131378   0.176419
# 2   XGBoost   1.900176  0.157455   0.209644

# %%
winner_name = summary_df.iloc[0]["model"]
runner_up = summary_df.iloc[1]
winner_row = summary_df.iloc[0]
improvement_pct = 100 * (runner_up["mean_RMSE"] - winner_row["mean_RMSE"]) / runner_up["mean_RMSE"]
print(f"Winner: {winner_name} (mean RMSE {winner_row['mean_RMSE']:.4f} vs {runner_up['model']}'s {runner_up['mean_RMSE']:.4f}, "
      f"{improvement_pct:.1f}% lower RMSE)")
per_target_df[per_target_df["model"] == winner_name].reset_index(drop=True)
# Out:
# Winner: CatBoost (mean RMSE 0.1477 vs LightGBM's 0.1764, 16.3% lower RMSE)
#       model           target      MAPE       MAE      RMSE
# 0  CatBoost   BlendProperty1  1.646019  0.076643  0.101386
# 1  CatBoost   BlendProperty2  0.394558  0.076793  0.097746
# 2  CatBoost   BlendProperty3  1.011695  0.149362  0.190382
# 3  CatBoost   BlendProperty4  0.436097  0.081134  0.115622
# 4  CatBoost   BlendProperty5  0.382855  0.077762  0.147471
# 5  CatBoost   BlendProperty6  0.365156  0.062655  0.095756
# 6  CatBoost   BlendProperty7  0.786210  0.148841  0.192361
# 7  CatBoost   BlendProperty8  1.282388  0.119089  0.164928
# 8  CatBoost   BlendProperty9  1.155317  0.190011  0.255844
# 9  CatBoost  BlendProperty10  0.274828  0.081145  0.115041

# %% [markdown]
# ## Explainability: SHAP on the winning model
#
# Which of the 400+ engineered features (cross-component stats, entropy,
# weighted interactions, z-scores, rank/diff features) actually drive each
# `BlendProperty` prediction, rather than just listing that they were
# engineered.

# %%
winner_model = fitted_models[winner_name]
shap_results = shap_summary(winner_model, X_val, feature_names, target_cols, top_n=10)

for target, top_features in shap_results.items():
    print(f"\n{target} — top 5 drivers:")
    print(top_features.head(5).to_string(index=False))
# Out:
# BlendProperty1 — top 5 drivers:
#             feature  mean_abs_shap
# Component5_fraction       0.674588
# Component2_fraction       0.298820
#  Weighted_Property1       0.285382
# Component4_fraction       0.215502
#      C3_P1_weighted       0.069169
#
# BlendProperty2 — top 5 drivers:
#             feature  mean_abs_shap
# Component5_fraction       0.616937
#  Weighted_Property2       0.282560
# Component2_fraction       0.249485
# Component3_fraction       0.175871
# Component4_fraction       0.158096
#
# BlendProperty3 — top 5 drivers:
#             feature  mean_abs_shap
# Component2_fraction       0.596998
#  Weighted_Property7       0.164940
# Component4_fraction       0.107604
# Component3_fraction       0.083723
# Component1_fraction       0.083499
#
# BlendProperty4 — top 5 drivers:
#             feature  mean_abs_shap
# Component5_fraction       0.661112
#  Weighted_Property4       0.309844
# Component2_fraction       0.285166
# Component4_fraction       0.188490
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 5))
top5 = shap_results["BlendProperty1"].head(5).iloc[::-1]
ax.barh(top5["feature"], top5["mean_abs_shap"], color="#2563eb")
ax.set_xlabel("mean |SHAP value|")
ax.set_title("Top 5 SHAP drivers — BlendProperty1")
fig.tight_layout()
fig.savefig("shap_blendproperty1.png", dpi=150)
plt.show()

# %% [markdown]
# ## Refit winner on full training data
#
# The comparison above used an 80% train / 20% val split to get an honest
# estimate of generalization error. For the final model used to score the
# test set, refit the winning architecture on 100% of the training data.

# %%
from src.modeling import build_candidate_models

final_model = build_candidate_models(random_state=42)[winner_name]
final_model.fit(X_scaled, y)

# Persist everything app.py needs to reproduce this exact preprocessing:
# the model, the fitted scaler, the expected feature column order, and the target names.
save_model(final_model, "models/blend_model.joblib")
save_model(scaler, "models/scaler.joblib")
save_model(feature_names, "models/feature_names.joblib")
save_model(target_cols, "models/target_cols.joblib")
print(f"Saved final {winner_name} model + preprocessing artifacts to models/")
# Out:
# Saved final CatBoost model + preprocessing artifacts to models/

# %% [markdown]
# ## Predict on test set and write submission

# %%
final_preds = final_model.predict(X_test_scaled)
submission = pd.DataFrame(final_preds, columns=target_cols)
submission.insert(0, "ID", test["ID"].values)
submission.to_csv("submission.csv", index=False)
submission.head()
# Out:
#    ID  BlendProperty1  BlendProperty2  BlendProperty3  BlendProperty4  BlendProperty5  BlendProperty6  BlendProperty7  \
# 0   1        0.154283        0.158025        0.728176        0.639414        0.322800        0.624987        0.656656
# 1   2       -0.702043       -0.586580       -1.056665        0.145610       -0.717844       -0.180796       -1.063921
# 2   3        1.707188        1.119134        1.170502        0.975599        2.348264        1.760866        1.119584
# 3   4       -0.382483        0.423544        0.861766       -0.592080        1.971424       -0.363673        0.845275
# 4   5        0.181754       -1.043110        1.020390        0.499987        2.177213        0.236732        0.978283
#
#    BlendProperty8  BlendProperty9  BlendProperty10
# 0        0.389442       -0.454269         0.361572
# 1       -1.114724       -0.692102         0.041738
# 2        1.905114        0.358847         2.145346
# 3        1.551944        0.586846        -0.976053
# ...
